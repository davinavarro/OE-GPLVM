# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Training data is 100 points in [0,1] inclusive regularly spaced
train_x = torch.linspace(0, 1, 100)
# True function is sin(2*pi*x) with Gaussian noise
train_y = torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * math.sqrt(0.04)
f, ax = plt.subplots(1, 1, figsize=(4, 3))
ax.plot(train_x.numpy(), train_y.numpy(), 'x')

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
    
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)

# %%
training_iter =  50
# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/50 - Loss: 0.918   lengthscale: 0.693   noise: 0.693
# Iter 2/50 - Loss: 0.886   lengthscale: 0.644   noise: 0.644
# Iter 3/50 - Loss: 0.851   lengthscale: 0.598   noise: 0.598
# Iter 4/50 - Loss: 0.813   lengthscale: 0.555   noise: 0.554
# Iter 5/50 - Loss: 0.771   lengthscale: 0.514   noise: 0.513
# Iter 6/50 - Loss: 0.724   lengthscale: 0.475   noise: 0.474
# Iter 7/50 - Loss: 0.675   lengthscale: 0.438   noise: 0.437
# Iter 8/50 - Loss: 0.625   lengthscale: 0.404   noise: 0.402
# Iter 9/50 - Loss: 0.577   lengthscale: 0.371   noise: 0.370
# Iter 10/50 - Loss: 0.534   lengthscale: 0.342   noise: 0.339
# Iter 11/50 - Loss: 0.494   lengthscale: 0.315   noise: 0.311
# Iter 12/50 - Loss: 0.457   lengthscale: 0.293   noise: 0.284
# Iter 13/50 - Loss: 0.421   lengthscale: 0.274   noise: 0.260
# Iter 14/50 - Loss: 0.385   lengthscale: 0.258   noise: 0.237
# Iter 15/50 - Loss: 0.349   lengthscale: 0.246   noise: 0.216
# Iter 16/50 - Loss: 0.314   lengthscale: 0.236   noise: 0.197
# Iter 17/50 - Loss: 0.279   lengthscale: 0.229   noise: 0.179
# Iter 18/50 - Loss: 0.244   lengthscale: 0.223   noise: 0.163
# Iter 19/50 - Loss: 0.209   lengthscale: 0.220   noise: 0.148
# Iter 20/50 - Loss: 0.175   lengthscale: 0.219   noise: 0.134
# Iter 21/50 - Loss: 0.141   lengthscale: 0.219   noise: 0.122
# Iter 22/50 - Loss: 0.107   lengthscale: 0.220   noise: 0.111
# Iter 23/50 - Loss: 0.075   lengthscale: 0.223   noise: 0.101
# Iter 24/50 - Loss: 0.044   lengthscale: 0.227   noise: 0.091
# Iter 25/50 - Loss: 0.014   lengthscale: 0.232   noise: 0.083
# Iter 26/50 - Loss: -0.014   lengthscale: 0.238   noise: 0.076
# Iter 27/50 - Loss: -0.039   lengthscale: 0.245   noise: 0.069
# Iter 28/50 - Loss: -0.062   lengthscale: 0.251   noise: 0.063
# Iter 29/50 - Loss: -0.082   lengthscale: 0.258   noise: 0.057
# Iter 30/50 - Loss: -0.099   lengthscale: 0.265   noise: 0.053
# Iter 31/50 - Loss: -0.113   lengthscale: 0.271   noise: 0.048
# Iter 32/50 - Loss: -0.124   lengthscale: 0.276   noise: 0.044
# Iter 33/50 - Loss: -0.132   lengthscale: 0.280   noise: 0.041
# Iter 34/50 - Loss: -0.138   lengthscale: 0.282   noise: 0.038
# Iter 35/50 - Loss: -0.141   lengthscale: 0.283   noise: 0.035
# Iter 36/50 - Loss: -0.142   lengthscale: 0.282   noise: 0.033
# Iter 37/50 - Loss: -0.142   lengthscale: 0.279   noise: 0.031
# Iter 38/50 - Loss: -0.141   lengthscale: 0.275   noise: 0.030
# Iter 39/50 - Loss: -0.139   lengthscale: 0.270   noise: 0.028
# Iter 40/50 - Loss: -0.136   lengthscale: 0.264   noise: 0.027
# Iter 41/50 - Loss: -0.134   lengthscale: 0.257   noise: 0.026
# Iter 42/50 - Loss: -0.131   lengthscale: 0.251   noise: 0.025
# Iter 43/50 - Loss: -0.128   lengthscale: 0.245   noise: 0.025
# Iter 44/50 - Loss: -0.126   lengthscale: 0.240   noise: 0.025
# Iter 45/50 - Loss: -0.125   lengthscale: 0.235   noise: 0.025
# Iter 46/50 - Loss: -0.125   lengthscale: 0.232   noise: 0.025
# Iter 47/50 - Loss: -0.126   lengthscale: 0.231   noise: 0.025
# Iter 48/50 - Loss: -0.127   lengthscale: 0.230   noise: 0.025
# Iter 49/50 - Loss: -0.130   lengthscale: 0.231   noise: 0.025
# Iter 50/50 - Loss: -0.132   lengthscale: 0.232   noise: 0.026

# %%
# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1, 51)
    observed_pred = likelihood(model(test_x))

# %%
with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, figsize=(4, 3))

    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-3, 3])
    ax.legend(['Observed Data', 'Mean', 'Confidence'])
